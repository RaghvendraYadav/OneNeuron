# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\dell\Corey Schafer\data1.csv')

# %%
df
# Out:
#     Age  All_Devs  Python  JavaScript
# 0    18     17784   20046       16446
# 1    19     16500   17100       16791
# 2    20     18012   20000       18942
# 3    21     20628   24744       21780
# 4    22     25206   30500       25704
# 5    23     30252   37732       29000
# 6    24     34368   41247       34372
# 7    25     38496   45372       37810
# 8    26     42000   48876       43515
# 9    27     46752   53850       46823
# 10   28     49320   57287       49293
# 11   29     53200   45000       53437
# 12   30     56000   50000       56373
# 13   31     62316   55000       62375
# 14   32     64928   70000       66674
# 15   33     67317   71496       68745
# 16   34     68748   75370       68746
# 17   35     73752   83640       74583
# 18   36     77232   84666       79000
# 19   37     78000   84392       78508
# 20   38     78508   78254       79996
# 21   39     79536   85000       80403
# 22   40     82488   87038       83820
# 23   41     88935   91991       88833
# ...

# %%
df.head()
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446
# 1   19     16500   17100       16791
# 2   20     18012   20000       18942
# 3   21     20628   24744       21780
# 4   22     25206   30500       25704

# %%
df.head(2)
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446
# 1   19     16500   17100       16791

# %%
df.head(20)
# Out:
#     Age  All_Devs  Python  JavaScript
# 0    18     17784   20046       16446
# 1    19     16500   17100       16791
# 2    20     18012   20000       18942
# 3    21     20628   24744       21780
# 4    22     25206   30500       25704
# 5    23     30252   37732       29000
# 6    24     34368   41247       34372
# 7    25     38496   45372       37810
# 8    26     42000   48876       43515
# 9    27     46752   53850       46823
# 10   28     49320   57287       49293
# 11   29     53200   45000       53437
# 12   30     56000   50000       56373
# 13   31     62316   55000       62375
# 14   32     64928   70000       66674
# 15   33     67317   71496       68745
# 16   34     68748   75370       68746
# 17   35     73752   83640       74583
# 18   36     77232   84666       79000
# 19   37     78000   84392       78508

# %%
df.tail()
# Out:
#     Age  All_Devs  Python  JavaScript
# 33   51     98988  108423       91660
# 34   52    100000  101407       99240
# 35   53    108923  112542      108000
# 36   54    105000  122870      105000
# 37   55    103117  120000      104000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df1=df.head()

# %%
df1
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446
# 1   19     16500   17100       16791
# 2   20     18012   20000       18942
# 3   21     20628   24744       21780
# 4   22     25206   30500       25704

# %%
df1.to_csv('FirstDataFrame.csv')

# %%
pwd()
# Out:
# 'C:\\Users\\dell\\OneNeuron'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7EAB-9F48
#
#  Directory of C:\Users\dell\OneNeuron
#
# 23-06-2022  11:53    <DIR>          .
# 23-06-2022  11:53    <DIR>          ..
# 23-06-2022  10:49    <DIR>          .ipynb_checkpoints
# 03-04-2022  16:54    <DIR>          __pycache__
# 25-05-2022  14:28             7,789 Abstraction and Inheritance.ipynb
# 25-03-2022  01:04                29 addition.py
# 28-05-2022  13:17           628,633 carbon_nanotubes.csv
# 21-06-2022  18:49             8,165 CassandraConnectionPython.ipynb
# 19-05-2022  20:05            12,106 Classes&Objects.ipynb
# 19-05-2022  20:03                 6 d.txt
# 13-06-2022  00:31           493,835 database.log
# 19-05-2022  18:00                41 File1
# 23-06-2022  11:51               153 FirstDataFrame.cdv
# 23-06-2022  11:53               153 FirstDataFrame.csv
# 25-01-2022  02:06            12,631 Function.ipynb
# 02-03-2022  01:14            10,120 Function1.ipynb
# ...

# %%
pd.read_csv('FirstDataFrame.csv')
# Out:
#    Unnamed: 0  Age  All_Devs  Python  JavaScript
# 0           0   18     17784   20046       16446
# 1           1   19     16500   17100       16791
# 2           2   20     18012   20000       18942
# 3           3   21     20628   24744       21780
# 4           4   22     25206   30500       25704

# %%
pd.read_csv('carbon_nanotubes.csv')
# Out:
#                                                      Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w'
# 2;1;0  679005;0 701318;0 017033;0 721039;0 730232;0                                            17014.0
#        717298;0 642129;0 231319;0 738414;0 65675;0                                            232369.0
#        489336;0 303751;0 088462;0 477676;0 263221;0                                            88712.0
#        413957;0 632996;0 040843;0 408823;0 657897;0                                            39796.0
#        334292;0 543401;0 15989;0  303349;0 558807;0                                           157373.0
# ...                                                                                                ...
# ...

# %%
df=pd.read_csv('C:\\Users\dell\Corey Schafer\data1.csv',sep='#')

# %%
df
# Out:
#     Age  All_Devs  Python JavaScript
# 0    18     17784   20046      16446
# 1    19     16500   17100      16791
# 2    20     18012   20000      18942
# 3    21     20628   24744      21780
# 4    22     25206   30500     25704s
# 5    23     30252   37732      29000
# 6    24     34368   41247      34372
# 7    25     38496   45372      37810
# 8    26     42000   48876      43515
# 9    27     46752   53850      46823
# 10   28     49320   57287      49293
# 11   29     53200   45000      53437
# 12   30     56000   50000      56373
# 13   31     62316   55000      62375
# 14   32     64928   70000      66674
# 15   33     67317   71496      68745
# 16   34     68748   75370      68746
# 17   35     73752   83640      74583
# 18   36     77232   84666      79000
# 19   37     78000   84392      78508
# 20   38     78508   78254      79996
# 21   39     79536   85000      80403
# 22   40     82488   87038      83820
# 23   41     88935   91991      88833
# ...

# %%
df=pd.read_csv('C:\\Users\dell\Corey Schafer\data1.csv',sep='#',header=None)

# %%
df
# Out:
#       0         1       2           3
# 0   Age  All_Devs  Python  JavaScript
# 1    18     17784   20046       16446
# 2    19     16500   17100       16791
# 3    20     18012   20000       18942
# 4    21     20628   24744       21780
# 5    22     25206   30500      25704s
# 6    23     30252   37732       29000
# 7    24     34368   41247       34372
# 8    25     38496   45372       37810
# 9    26     42000   48876       43515
# 10   27     46752   53850       46823
# 11   28     49320   57287       49293
# 12   29     53200   45000       53437
# 13   30     56000   50000       56373
# 14   31     62316   55000       62375
# 15   32     64928   70000       66674
# 16   33     67317   71496       68745
# 17   34     68748   75370       68746
# 18   35     73752   83640       74583
# 19   36     77232   84666       79000
# 20   37     78000   84392       78508
# 21   38     78508   78254       79996
# 22   39     79536   85000       80403
# 23   40     82488   87038       83820
# ...

# %%
import pandas as pd
df=pd.read_csv('C:\\Users\dell\Corey Schafer\data1.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-6731315d3e09> in <module>
# ----> 1 import pandas as pd
#       2 df=pd.read_csv('C:\\Users\dell\Corey Schafer\data1.csv')
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\__init__.py in <module>
#      49 import pandas.core.config_init
#      50
# ---> 51 from pandas.core.api import (
#      52     # dtype
#      53     Int8Dtype,
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\core\api.py in <module>
#      13
#      14 from pandas.core.algorithms import factorize, unique, value_counts
# ---> 15 from pandas.core.arrays import Categorical
#      16 from pandas.core.arrays.boolean import BooleanDtype
#      17 from pandas.core.arrays.floating import Float32Dtype, Float64Dtype
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\core\arrays\__init__.py in <module>
#       4     ExtensionScalarOpsMixin,
#       5 )
# ...

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\__init__.py in <module>
#     139 )
#     140
# --> 141 import pandas.api
#     142 from pandas.util._print_versions import show_versions
#     143
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\api\__init__.py in <module>
#       1 """ public toolkit API """
# ----> 2 from pandas.api import extensions, indexers, types  # noqa
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\api\types\__init__.py in <module>
#       5 from pandas._libs.lib import infer_dtype
#       6
# ----> 7 from pandas.core.dtypes.api import *  # noqa: F401, F403
#       8 from pandas.core.dtypes.concat import union_categoricals
#       9 from pandas.core.dtypes.dtypes import (
#
# ...

# %%
import pandas as pd

# %%
pd.read_csv('C:\\Users\dell\Corey Schafer\data1.csv')
# Out:
#    Age#All_Devs#Python#JavaScript
# 0            18#17784#20046#16446
# 1            19#16500#17100#16791
# 2            20#18012#20000#18942
# 3            21#20628#24744#21780
# 4           22#25206#30500#25704s
# 5            23#30252#37732#29000
# 6            24#34368#41247#34372
# 7            25#38496#45372#37810
# 8            26#42000#48876#43515
# 9            27#46752#53850#46823
# 10           28#49320#57287#49293
# 11           29#53200#45000#53437
# 12           30#56000#50000#56373
# 13           31#62316#55000#62375
# 14           32#64928#70000#66674
# 15           33#67317#71496#68745
# 16           34#68748#75370#68746
# 17           35#73752#83640#74583
# 18           36#77232#84666#79000
# 19           37#78000#84392#78508
# 20           38#78508#78254#79996
# 21           39#79536#85000#80403
# 22           40#82488#87038#83820
# 23           41#88935#91991#88833
# 24          42#90000#100000#91660
# 25           43#90056#94796#87892
# ...

# %%
df=pd.read_csv('C:\\Users\dell\Corey Schafer\data1.csv',sep='#')

# %%
df
# Out:
#     Age  All_Devs  Python JavaScript
# 0    18     17784   20046      16446
# 1    19     16500   17100      16791
# 2    20     18012   20000      18942
# 3    21     20628   24744      21780
# 4    22     25206   30500     25704s
# 5    23     30252   37732      29000
# 6    24     34368   41247      34372
# 7    25     38496   45372      37810
# 8    26     42000   48876      43515
# 9    27     46752   53850      46823
# 10   28     49320   57287      49293
# 11   29     53200   45000      53437
# 12   30     56000   50000      56373
# 13   31     62316   55000      62375
# 14   32     64928   70000      66674
# 15   33     67317   71496      68745
# 16   34     68748   75370      68746
# 17   35     73752   83640      74583
# 18   36     77232   84666      79000
# 19   37     78000   84392      78508
# 20   38     78508   78254      79996
# 21   39     79536   85000      80403
# 22   40     82488   87038      83820
# 23   41     88935   91991      88833
# ...

# %%
df=pd.read_csv('C:\\Users\dell\Corey Schafer\data1.csv',sep='#',header=None)

# %%
df
# Out:
#       0         1       2           3
# 0   Age  All_Devs  Python  JavaScript
# 1    18     17784   20046       16446
# 2    19     16500   17100       16791
# 3    20     18012   20000       18942
# 4    21     20628   24744       21780
# 5    22     25206   30500      25704s
# 6    23     30252   37732       29000
# 7    24     34368   41247       34372
# 8    25     38496   45372       37810
# 9    26     42000   48876       43515
# 10   27     46752   53850       46823
# 11   28     49320   57287       49293
# 12   29     53200   45000       53437
# 13   30     56000   50000       56373
# 14   31     62316   55000       62375
# 15   32     64928   70000       66674
# 16   33     67317   71496       68745
# 17   34     68748   75370       68746
# 18   35     73752   83640       74583
# 19   36     77232   84666       79000
# 20   37     78000   84392       78508
# 21   38     78508   78254       79996
# 22   39     79536   85000       80403
# 23   40     82488   87038       83820
# ...

# %%
# Giving the header by the users using name tag

f=pd.read_csv('C:\\Users\dell\Corey Schafer\data1.csv',sep='#',header=None,names=['A','B','C','D'])

# %%
f
# Out:
#       A         B       C           D
# 0   Age  All_Devs  Python  JavaScript
# 1    18     17784   20046       16446
# 2    19     16500   17100       16791
# 3    20     18012   20000       18942
# 4    21     20628   24744       21780
# 5    22     25206   30500      25704s
# 6    23     30252   37732       29000
# 7    24     34368   41247       34372
# 8    25     38496   45372       37810
# 9    26     42000   48876       43515
# 10   27     46752   53850       46823
# 11   28     49320   57287       49293
# 12   29     53200   45000       53437
# 13   30     56000   50000       56373
# 14   31     62316   55000       62375
# 15   32     64928   70000       66674
# 16   33     67317   71496       68745
# 17   34     68748   75370       68746
# 18   35     73752   83640       74583
# 19   36     77232   84666       79000
# 20   37     78000   84392       78508
# 21   38     78508   78254       79996
# 22   39     79536   85000       80403
# 23   40     82488   87038       83820
# ...

# %%
#Skips the rows tht we donot want in below using list comprehension we have used on Odd values
df=pd.read_csv('C:\\Users\dell\Data\survey_results_public.csv',skiprows=[i  for i in range(83439)  if i%2==0 ])
df
# Out:
#            1                     I am a developer by profession  \
# 0          3  I am not primarily a developer, but I write co...
# 1          5                     I am a developer by profession
# 2          7                        I code primarily as a hobby
# 3          9                     I am a developer by profession
# 4         11                     I am a developer by profession
# ...      ...                                                ...
# 41714  83431                     I am a developer by profession
# 41715  83433                     I am a developer by profession
# 41716  83435                     I am a developer by profession
# 41717  83437                     I am a developer by profession
# 41718  83439                     I am a developer by profession
#
#       Independent contractor, freelancer, or self-employed  \
# 0                                     Student, full-time
# 1      Independent contractor, freelancer, or self-em...
# ...

# %%
# Out:
#           10                     I am a developer by profession  \
# 0         11                     I am a developer by profession
# 1         12                     I am a developer by profession
# 2         13                     I am a developer by profession
# 3         14             I am a student who is learning to code
# 4         15  I used to be a developer by profession, but no...
# ...      ...                                                ...
# 83424  83435                     I am a developer by profession
# 83425  83436                     I am a developer by profession
# 83426  83437                     I am a developer by profession
# 83427  83438                     I am a developer by profession
# 83428  83439                     I am a developer by profession
#
#                                       Employed full-time  \
# 0                                     Employed full-time
# 1                                     Employed full-time
# ...

# %%
# Nan Value for some values  na_values Cange values to NAN Values
df=pd.read_csv('C:\\Users\dell\Data\survey_results_public.csv',na_values=['Neither easy nor difficult'])

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# using float and int datatype for cloumn gives the manipulations for tht
df.describe()
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
type(df['ResponseId'])
# Out:
# pandas.core.series.Series

# %%
#dtypes gives the data type of all the columns
df.dtypes
# Out:
# ResponseId                        int64
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                       object
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# ...

# %%
import pandas as pd
df=pd.read_csv('C:\\Users\dell\Data\survey_results_public.csv')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.to_csv('result2.csv',header=False,index=False,columns=['Employment','Country'])

# %%
df

# %%
df.tail()

# %%
import pandas as pd

# %%
pd.read_excel('C:\\Users\dell\OneNeuron\AAA.xlsx')
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
pd.read_excel('C:\\Users\dell\OneNeuron\sample-excel-master\AAA.xlsx',sheet_name='Add your take on balances')
# Out:
#     Unnamed: 0  Unnamed: 1                                         Unnamed: 2  \
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                                NaN
# 2          NaN         NaN                                                NaN
# 3          NaN         NaN                                                NaN
# 4          NaN         NaN                                                NaN
# 5          NaN         NaN                                                NaN
# 6          NaN         NaN                                                NaN
# 7          NaN         NaN                                                NaN
# 8          NaN         NaN                                                NaN
# 9          NaN         NaN                                                NaN
# 10         NaN         NaN                                                NaN
# ...

# %%
df=pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool')

# %%
df
# Out:
# [       Season   Age                                     Tm  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
df[4]
# Out:
#        Season   Age   Tm   Lg   Pos      G       MP   PER    TS%   3PAr  ...  \
# 0     2009-10  20.0  OKC  NBA    PF   73.0   1323.0  15.2  0.562  0.005  ...
# 1     2010-11  21.0  OKC  NBA    PF   82.0   2216.0  17.7  0.579  0.002  ...
# 2     2011-12  22.0  OKC  NBA    PF   66.0   1792.0  19.0  0.556  0.006  ...
# 3     2012-13  23.0  OKC  NBA    PF   80.0   2486.0  19.4  0.612  0.073  ...
# 4     2013-14  24.0  OKC  NBA    PF   81.0   2666.0  19.6  0.576  0.061  ...
# 5     2014-15  25.0  OKC  NBA    PF   64.0   2116.0  16.6  0.549  0.261  ...
# 6     2015-16  26.0  OKC  NBA    PF   78.0   2500.0  13.9  0.533  0.212  ...
# 7     2016-17  27.0  TOT  NBA    PF   79.0   2422.0  16.4  0.566  0.323  ...
# 8     2016-17  27.0  ORL  NBA    PF   56.0   1710.0  17.5  0.569  0.304  ...
# 9     2016-17  27.0  TOR  NBA    PF   23.0    712.0  13.8  0.556  0.369  ...
# 10    2017-18  28.0  TOR  NBA    PF   76.0   2093.0  14.7  0.574  0.379  ...
# ...

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 6

# %%
df[3].to_csv
