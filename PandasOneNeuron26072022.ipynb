# %%
import pandas as pd
titanic_train=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(titanic_train.dtypes)
# Out:
# pandas.core.series.Series

# %%
dt=titanic_train.dtypes

# %%
dt['Parch']
# Out:
# dtype('int64')

# %%
dt[0]
# Out:
# dtype('int64')

# %%
dt[0:4]
# Out:
# PassengerId     int64
# Survived        int64
# Pclass          int64
# Name           object
# dtype: object

# %%
dt[0:100:2]
# Out:
# PassengerId     int64
# Pclass          int64
# Sex            object
# SibSp           int64
# Ticket         object
# Cabin          object
# dtype: object

# %%
titanic_train['Age'][10:100]
# Out:
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
#       ...
# 95     NaN
# 96    71.0
# 97    23.0
# 98    34.0
# 99    34.0
# Name: Age, Length: 90, dtype: float64

# %%
titanic_train[::-1]
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 889          890         1       1
# 888          889         0       3
# 887          888         1       1
# 886          887         0       2
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0              1         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 890                                Dooley, Mr. Patrick    male  32.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train['Age'][::-1]
# Out:
# 890    32.0
# 889    26.0
# 888     NaN
# 887    19.0
# 886    27.0
#        ...
# 4      35.0
# 3      35.0
# 2      26.0
# 1      38.0
# 0      22.0
# Name: Age, Length: 891, dtype: float64

# %%
list(titanic_train['Age'][::2])
# Out:
# [22.0,
#  26.0,
#  35.0,
#  54.0,
#  27.0,
#  4.0,
#  20.0,
#  14.0,
#  2.0,
#  31.0,
#  35.0,
#  15.0,
#  8.0,
#  nan,
#  nan,
#  40.0,
#  nan,
#  28.0,
#  nan,
#  18.0,
#  40.0,
#  nan,
#  19.0,
#  nan,
#  nan,
#  7.0,
#  49.0,
#  65.0,
#  21.0,
#  5.0,
#  22.0,
#  45.0,
#  nan,
#  29.0,
#  17.0,
#  32.0,
#  21.0,
#  32.0,
#  nan,
#  0.83,
#  22.0,
#  nan,
#  17.0,
#  16.0,
#  23.0,
#  29.0,
#  46.0,
#  59.0,
#  71.0,
#  34.0,
#  28.0,
#  21.0,
#  37.0,
#  21.0,
#  38.0,
#  47.0,
#  22.0,
#  17.0,
#  70.5,
#  24.0,
#  21.0,
#  32.5,
#  54.0,
#  nan,
#  nan,
#  33.0,
#  47.0,
#  25.0,
#  19.0,
#  16.0,
#  nan,
#  24.0,
#  18.0,
#  27.0,
#  36.5,
#  51.0,
#  55.5,
#  nan,
#  16.0,
#  nan,
#  44.0,
#  26.0,
#  1.0,
#  nan,
#  nan,
#  61.0,
#  1.0,
#  56.0,
#  nan,
#  30.0,
#  nan,
#  9.0,
#  4.0,
#  nan,
#  40.0,
#  32.0,
#  19.0,
#  44.0,
#  nan,
#  nan,
#  28.0,
#  34.0,
#  18.0,
#  32.0,
#  16.0,
#  24.0,
#  22.0,
#  nan,
#  27.0,
#  32.0,
#  16.0,
#  51.0,
#  38.0,
#  19.0,
# ...

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic_train.dtypes[titanic_train.dtypes=='object']# Name of columns with Object dtypes if Truw then GIve Name and Dtypes Of columns
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic_train.dtypes[titanic_train.dtypes=='object'].index#Dtypes object Columns Name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic_train_cat=titanic_train[titanic_train.dtypes[titanic_train.dtypes=='object'].index]

# %%
titanic_train_cat.describe()# For Categorical or Object Daata Types It has given Describe
# Out:
#                                 Name   Sex  Ticket Cabin Embarked
# count                            891   891     891   204      889
# unique                           891     2     681   147        3
# top     Graham, Miss. Margaret Edith  male  347082    G6        S
# freq                               1   577       7     4      644

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic_train[['Age','Fare']]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
type(titanic_train[['Age','Fare']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(titanic_train['Age'])
# Out:
# pandas.core.series.Series

# %%
titanic_train[['Age']].isnull()
# Out:
#        Age
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 886  False
# 887  False
# 888   True
# 889  False
# 890  False
#
# [891 rows x 1 columns]

# %%
titanic_train[titanic_train.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
import numpy as np

# %%
titanic_train_age_null=np.where(titanic_train['Age'].isnull()==True)

# %%
titanic_train_age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
titanic_train[['Age','Pclass']]
# Out:
#       Age  Pclass
# 0    22.0       3
# 1    38.0       1
# 2    26.0       3
# 3    35.0       1
# 4    35.0       3
# ..    ...     ...
# 886  27.0       2
# 887  19.0       1
# 888   NaN       3
# 889  26.0       1
# 890  32.0       3
#
# [891 rows x 2 columns]

# %%
titanic_train.iloc[titanic_train_age_null]# Gives Rows On the basis of index index location(iloc)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic_train.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
titanic_train.iloc[2:22]
# Out:
#     PassengerId  Survived  Pclass  \
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic_train.iloc[[1,2,3,4,5,6,7,8]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# ...

# %%
titanic_train.iloc[[1,2,3,4,5,6,7,8]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# ...

# %%
titanic_train.iloc[np.where(titanic_train['Fare']==max(titanic_train['Fare']))]['Name']# Name of Person Who  Has Max Fare
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic_train[titanic_train['Fare']==titanic_train['Fare'].max()]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
list(titanic_train[titanic_train['Age']==24]['Name'])
# Out:
# ['Celotti, Mr. Francesco',
#  'Baxter, Mr. Quigg Edmond',
#  'Madsen, Mr. Fridtjof Arne',
#  'Giglio, Mr. Victor',
#  'Hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)',
#  'Yrois, Miss. Henriette ("Mrs Harbeck")',
#  'Ali, Mr. Ahmed',
#  'Leyson, Mr. Robert William Norman',
#  'Hamalainen, Mrs. William (Anna)',
#  'Haas, Miss. Aloisia',
#  'Mineff, Mr. Ivan',
#  'Hays, Miss. Margaret Bechstein',
#  'Kantor, Mrs. Sinai (Miriam Sternin)',
#  'Fortune, Miss. Alice Elizabeth',
#  'Brown, Miss. Amelia "Mildred"',
#  'Aubart, Mme. Leontine Pauline',
#  'Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengtsson)',
#  'Richards, Mrs. Sidney (Emily Hocking)',
#  'Svensson, Mr. Olof',
#  'Coleff, Mr. Satio',
#  'Davies, Mr. Alfred J',
#  'Jacobsohn, Mrs. Sidney Samuel (Amy Frances Christy)',
#  'Herman, Miss. Alice',
#  'Sagesser, Mlle. Emma',
#  'Hickman, Mr. Leonard Mark',
#  'Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")',
#  'McNamee, Mr. Neal',
#  'Lievens, Mr. Rene Aime',
# ...

# %%
titanic_train.loc[titanic_train['Age']==24]['Name']
# Out:
# 89                                Celotti, Mr. Francesco
# 118                             Baxter, Mr. Quigg Edmond
# 127                            Madsen, Mr. Fridtjof Arne
# 139                                   Giglio, Mr. Victor
# 142    Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 199               Yrois, Miss. Henriette ("Mrs Harbeck")
# 210                                       Ali, Mr. Ahmed
# 234                    Leyson, Mr. Robert William Norman
# 247                      Hamalainen, Mrs. William (Anna)
# 293                                  Haas, Miss. Aloisia
# 294                                     Mineff, Mr. Ivan
# 310                       Hays, Miss. Margaret Bechstein
# 316                  Kantor, Mrs. Sinai (Miriam Sternin)
# 341                       Fortune, Miss. Alice Elizabeth
# 345                        Brown, Miss. Amelia "Mildred"
# 369                        Aubart, Mme. Leontine Pauline
# ...

# %%
titanic_train[titanic_train['Cabin'].isnull()]['Age']
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 5       NaN
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 687, dtype: float64

# %%
titanic_train['Age'][titanic_train['Cabin'].isnull()]
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 5       NaN
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 687, dtype: float64

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train[(titanic_train.Survived==1) & (titanic_train.Sex=='male')]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
import numpy as np
import pandas as pd
l=[1,2,3,4,5]

# %%
pd.Series(l)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
dict1={
    'key':'Sudh',
    'title':'Yadav',
    'mail_id':'Rag@gmail.com'
}

# %%
pd.DataFrame(dict1,index=['Key','title','mail_id'])
# Out:
#           key  title        mail_id
# Key      Sudh  Yadav  Rag@gmail.com
# title    Sudh  Yadav  Rag@gmail.com
# mail_id  Sudh  Yadav  Rag@gmail.com

# %%
arr=np.random.randn(3,4)

# %%
arr
# Out:
# array([[ 0.03805718,  0.28870786,  0.79319394,  0.31722926],
#        [ 1.5051731 , -0.50228798, -0.76650434,  1.92185109],
#        [ 0.94450867,  0.11774146,  0.50663651,  0.38614971]])

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0  0.038057  0.288708  0.793194  0.317229
# 1  1.505173 -0.502288 -0.766504  1.921851
# 2  0.944509  0.117741  0.506637  0.386150

# %%
pd.Series(np.array([1,2,3,4]))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
ser=pd.Series(np.array([1,2,3,4]),index=['a','b','c','d'])

# %%
ser
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int32

# %%
ser['b']
# Out:
# 2

# %%
ser.iloc['b']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-e3fcbe6b63a7> in <module>
# ----> 1 ser.iloc['b']
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1496             key = item_from_zerodim(key)
#    1497             if not is_integer(key):
# -> 1498                 raise TypeError("Cannot index by location index with a non-integer key")
#    1499
#    1500             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
ser.iloc[2]
# Out:
# 3

# %%
ser.loc['b']
# Out:
# 2

# %%
ser1=pd.Series(np.array([4,5,6,7]),index=[45,51,62,75])

# %%
ser1
# Out:
# 45    4
# 51    5
# 62    6
# 75    7
# dtype: int32

# %%
ser1.iloc[51]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-280a5a11aba7> in <module>
# ----> 1 ser1.iloc[51]
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1499
#    1500             # validate the location
# -> 1501             self._validate_integer(key, axis)
#    1502
#    1503             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1442         len_axis = len(self.obj._get_axis(axis))
# ...

# %%
ser1.loc[51]
# Out:
# 5

# %%
pd.DataFrame(np.random.randint(3,6,(4,5)))
# Out:
#    0  1  2  3  4
# 0  5  4  5  4  4
# 1  5  5  4  3  4
# 2  4  4  4  5  3
# 3  5  3  4  3  4

# %%
df=pd.DataFrame(np.random.randint(3,6,(4,5)),index=['a','b','c','d'],columns=['x','y','z','u','v'])

# %%
df
# Out:
#    x  y  z  u  v
# a  3  4  4  5  3
# b  3  3  4  4  4
# c  4  4  4  5  3
# d  4  4  4  5  5

# %%
df.loc[['c','d'],['z','u']]# using Column Names with ,
# Out:
#    z  u
# c  4  5
# d  4  5

# %%
df.loc['c':'d','z':'u']# using Column names with  :
# Out:
#    z  u
# c  4  5
# d  4  5

# %%
df.iloc[2:4,2:4]
# Out:
#    z  u
# c  4  5
# d  4  5

# %%
df.iloc[[2,3],[2,3]]#  Consistence Column index using Commas
# Out:
#    z  u
# c  4  5
# d  4  5

# %%
df['New Column']=df['x']+df['y']

# %%
df
# Out:
#    x  y  z  u  v  New Column
# a  3  4  4  5  3           7
# b  3  3  4  4  4           6
# c  4  4  4  5  3           8
# d  4  4  4  5  5           8

# %%
# Drop some of the Column
df.drop('x') # it will see indexes not column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-49bdd6ba5dad> in <module>
#       1 # Drop some of the Column
# ----> 2 df.drop('x')
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df.drop('x',axis=1)# means column name it will search x column is dropped her
# Out:
#    y  z  u  v  New Column
# a  4  4  5  3           7
# b  3  4  4  4           6
# c  4  4  5  3           8
# d  4  4  5  5           8

# %%
df# here still we have x column so we need to change it permanently
# Out:
#    x  y  z  u  v  New Column
# a  3  4  4  5  3           7
# b  3  3  4  4  4           6
# c  4  4  4  5  3           8
# d  4  4  4  5  5           8

# %%
df.drop('x',axis=1,inplace = True)# we have drop column name and to permentantly Dropp we will use inplace so tht i will achange the real Df

# %%
df# here we cn see tht df hasno column x now
# Out:
#    y  z  u  v  New Column
# a  4  4  5  3           7
# b  3  4  4  4           6
# c  4  4  5  3           8
# d  4  4  5  5           8

# %%
# Drop the rows using index name
df.drop('c')# here we will see c row is deleted but no permanent
# Out:
#    y  z  u  v  New Column
# a  4  4  5  3           7
# b  3  4  4  4           6
# d  4  4  5  5           8

# %%
df
# Out:
#    y  z  u  v  New Column
# a  4  4  5  3           7
# b  3  4  4  4           6
# c  4  4  5  3           8
# d  4  4  5  5           8

# %%
# Drop the row permanently using inplace
df.drop('c',inplace=True)# using inplace to drop and permannently chnge the df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-0456b8a65eac> in <module>
#       1 # Drop the row permanently using inplace
# ----> 2 df.drop('c',inplace=True)# using inplace to drop and permannently chnge the df
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
# ...

# %%
df
# Out:
#    y  z  u  v  New Column
# a  4  4  5  3           7
# b  3  4  4  4           6
# d  4  4  5  5           8

# %%
np.random.rand(4,5)
# Out:
# array([[0.75693407, 0.38379642, 0.85071846, 0.50787682, 0.68295706],
#        [0.15050078, 0.73754964, 0.46821863, 0.43383198, 0.9560739 ],
#        [0.60674251, 0.91424873, 0.11279298, 0.61585084, 0.32242383],
#        [0.08195223, 0.7252451 , 0.45660999, 0.56462491, 0.34360861]])

# %%
np.random.seed(23)# having same dataSet sir has so for tht we have used tht
df=pd.DataFrame(np.random.randn(4,5),index=['a','b','c','d'],columns=['x','y','z','u','v'])# randn has negative and positive values

# %%
df[df<0]# To give all the negative values
# Out:
#           x         y         z         u         v
# a       NaN       NaN -0.777619       NaN       NaN
# b -1.051082 -0.367548 -1.137460 -1.322148       NaN
# c -0.347459       NaN       NaN       NaN -1.043450
# d -1.009942       NaN       NaN -1.838068 -0.938769

# %%
df.values[df.values<0]# list where value is lss than 0
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
l=[]
for i in range(0,4):
    for j in range(0,5):
        if df.iloc[i,j] < 0:
            l.append(df.iloc[i,j])
l
# Out:
# [-0.7776194131918178,
#  -1.0510815639071178,
#  -0.3675481161171661,
#  -1.1374596907250272,
#  -1.3221475225908594,
#  -0.34745899102186334,
#  -1.0434500017467254,
#  -1.0099418765878465,
#  -1.8380677677579502,
#  -0.9387686311201282]

# %%
df.values[df.iloc[0:5]<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
df.values[df.index,df.columns]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-108-0d9ba6bcc8f3> in <module>
# ----> 1 df.values[df.index,df.columns]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
for i in df.columns:
    for j in df.index:
        if df.loc[j,i]<0:
            print(i,j,df.loc[j,i])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
l=df.values[df<0]
for i in df.columns:
    for j in df.index:
        if df[i][j] in l:
            print(i,j,df[i][j])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
l
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
d={'Key1':[1,2,3,4,np.nan],'key2':['Sudh','Kumar',4,5,6],'Key3':[np.nan,np.nan,np.nan,3,8]}
df=pd.DataFrame(d)

# %%
df
# Out:
#    Key1   key2  Key3
# 0   1.0   Sudh   NaN
# 1   2.0  Kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna()# all the rows having even a single NaN Value
# Out:
#    Key1 key2  Key3
# 3   4.0    5   3.0

# %%
df
# Out:
#    Key1   key2  Key3
# 0   1.0   Sudh   NaN
# 1   2.0  Kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(axis=1)# Drop column having even a single Nan Value
# Out:
#     key2
# 0   Sudh
# 1  Kumar
# 2      4
# 3      5
# 4      6

# %%
df.dropna(thresh=0)
# Out:
#    Key1   key2  Key3
# 0   1.0   Sudh   NaN
# 1   2.0  Kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=1,axis=1)
# Out:
#    Key1   key2  Key3
# 0   1.0   Sudh   NaN
# 1   2.0  Kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=2)
# Out:
#    Key1   key2  Key3
# 0   1.0   Sudh   NaN
# 1   2.0  Kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=3)# it shoult have matleast three values
# Out:
#    Key1 key2  Key3
# 3   4.0    5   3.0

# %%
df.dropna(thresh=3,axis=1)# Drop key 3 Column bcoz it sholu have atleast three Values
# Out:
#    Key1   key2
# 0   1.0   Sudh
# 1   2.0  Kumar
# 2   3.0      4
# 3   4.0      5
# 4   NaN      6

# %%
df.fillna('Sudh')
# Out:
#    Key1   key2  Key3
# 0   1.0   Sudh  Sudh
# 1   2.0  Kumar  Sudh
# 2   3.0      4  Sudh
# 3   4.0      5   3.0
# 4  Sudh      6   8.0

# %%
df.fillna(value=df['Key1'].mean())
# Out:
#    Key1   key2  Key3
# 0   1.0   Sudh   2.5
# 1   2.0  Kumar   2.5
# 2   3.0      4   2.5
# 3   4.0      5   3.0
# 4   2.5      6   8.0

# %%
df
# Out:
#    Key1   key2  Key3
# 0   1.0   Sudh   NaN
# 1   2.0  Kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
d1={
    'name':['Sudh','Vishal','Ram','Krish','Umang'],'Mail_ID':['S@gmail.com','Vi@gmail.com','R@gmail.com','K@gmail.com','Umang@gmail.com'],'Salary':[100,200,500,200,500]    
}
df1=pd.DataFrame(d1)

# %%
df1
# Out:
#      name          Mail_ID  Salary
# 0    Sudh      S@gmail.com     100
# 1  Vishal     Vi@gmail.com     200
# 2     Ram      R@gmail.com     500
# 3   Krish      K@gmail.com     200
# 4   Umang  Umang@gmail.com     500

# %%
df1.groupby('name').sum()
# Out:
#         Salary
# name
# Krish      200
# Ram        500
# Sudh       100
# Umang      500
# Vishal     200

# %%
df1.groupby('Mail_ID').describe()
# Out:
#                 Salary
#                  count   mean std    min    25%    50%    75%    max
# Mail_ID
# K@gmail.com        1.0  200.0 NaN  200.0  200.0  200.0  200.0  200.0
# R@gmail.com        1.0  500.0 NaN  500.0  500.0  500.0  500.0  500.0
# S@gmail.com        1.0  100.0 NaN  100.0  100.0  100.0  100.0  100.0
# Umang@gmail.com    1.0  500.0 NaN  500.0  500.0  500.0  500.0  500.0
# Vi@gmail.com       1.0  200.0 NaN  200.0  200.0  200.0  200.0  200.0

# %%
df1.groupby('Mail_ID').describe().loc['Umang@gmail.com']
# Out:
# Salary  count      1.0
#         mean     500.0
#         std        NaN
#         min      500.0
#         25%      500.0
#         50%      500.0
#         75%      500.0
#         max      500.0
# Name: Umang@gmail.com, dtype: float64

# %%
df1.groupby('Mail_ID').describe().loc['Umang@gmail.com']['Salary']
# Out:
# count      1.0
# mean     500.0
# std        NaN
# min      500.0
# 25%      500.0
# 50%      500.0
# 75%      500.0
# max      500.0
# Name: Umang@gmail.com, dtype: float64

# %%
df1.groupby('Mail_ID').describe().loc['Umang@gmail.com']['Salary']['mean']
# Out:
# 500.0

# %%
df1.groupby('Mail_ID').describe()
# Out:
#                 Salary
#                  count   mean std    min    25%    50%    75%    max
# Mail_ID
# K@gmail.com        1.0  200.0 NaN  200.0  200.0  200.0  200.0  200.0
# R@gmail.com        1.0  500.0 NaN  500.0  500.0  500.0  500.0  500.0
# S@gmail.com        1.0  100.0 NaN  100.0  100.0  100.0  100.0  100.0
# Umang@gmail.com    1.0  500.0 NaN  500.0  500.0  500.0  500.0  500.0
# Vi@gmail.com       1.0  200.0 NaN  200.0  200.0  200.0  200.0  200.0

# %%
df1.groupby('Mail_ID').describe().T # Transpose rowa into column nd column into rows
# Out:
# Mail_ID       K@gmail.com  R@gmail.com  S@gmail.com  Umang@gmail.com  \
# Salary count          1.0          1.0          1.0              1.0
#        mean         200.0        500.0        100.0            500.0
#        std            NaN          NaN          NaN              NaN
#        min          200.0        500.0        100.0            500.0
#        25%          200.0        500.0        100.0            500.0
#        50%          200.0        500.0        100.0            500.0
#        75%          200.0        500.0        100.0            500.0
#        max          200.0        500.0        100.0            500.0
#
# Mail_ID       Vi@gmail.com
# Salary count           1.0
#        mean          200.0
#        std             NaN
#        min           200.0
#        25%           200.0
#        50%           200.0
#        75%           200.0
#        max           200.0

# %%
aar1=np.random.randn(3,4)

# %%
aar2=np.random.randn(3,4)

# %%
aar3=np.random.randn(3,4)

# %%
df1=pd.DataFrame(aar1,columns=['A','B','C','D'],index=[0,1,2])

# %%
df2=pd.DataFrame(aar1,columns=['A','B','C','D'],index=[0,1,2])

# %%
df3=pd.DataFrame(aar1,columns=['A','B','C','D'],index=[0,1,2])

# %%
df1
# Out:
#           A         B         C         D
# 0 -1.080565  0.010229  0.437830  1.327788
# 1 -0.251145  1.593111  0.170818 -0.709254
# 2 -0.133025 -0.017357 -0.101093 -0.564040

# %%
df2
# Out:
#           A         B         C         D
# 0 -1.080565  0.010229  0.437830  1.327788
# 1 -0.251145  1.593111  0.170818 -0.709254
# 2 -0.133025 -0.017357 -0.101093 -0.564040

# %%
df3
# Out:
#           A         B         C         D
# 0 -1.080565  0.010229  0.437830  1.327788
# 1 -0.251145  1.593111  0.170818 -0.709254
# 2 -0.133025 -0.017357 -0.101093 -0.564040

# %%
df4=pd.concat([df1,df2,df3])# Concate more rows at the end

# %%
df5=pd.concat([df1,df2,df3],axis=1)# concat columns

# %%
df4.iloc[1:6,:]
# Out:
#           A         B         C         D
# 1 -0.251145  1.593111  0.170818 -0.709254
# 2 -0.133025 -0.017357 -0.101093 -0.564040
# 0 -1.080565  0.010229  0.437830  1.327788
# 1 -0.251145  1.593111  0.170818 -0.709254
# 2 -0.133025 -0.017357 -0.101093 -0.564040

# %%
df4.loc[2]
# Out:
#           A         B         C        D
# 2 -0.133025 -0.017357 -0.101093 -0.56404
# 2 -0.133025 -0.017357 -0.101093 -0.56404
# 2 -0.133025 -0.017357 -0.101093 -0.56404

# %%
df4.iloc[2]
# Out:
# A   -0.133025
# B   -0.017357
# C   -0.101093
# D   -0.564040
# Name: 2, dtype: float64

# %%
df5.iloc[:,4]
# Out:
# 0   -1.080565
# 1   -0.251145
# 2   -0.133025
# Name: A, dtype: float64

# %%
df5.iloc[:,1:4]
# Out:
#           B         C         D
# 0  0.010229  0.437830  1.327788
# 1  1.593111  0.170818 -0.709254
# 2 -0.017357 -0.101093 -0.564040

# %%
df6=pd.DataFrame(aar1,columns=['A','B','C','D'],index=[0,1,2])

# %%
df7=pd.DataFrame(aar2,columns=['A','B','C','D'],index=[3,4,5])

# %%
df8=pd.DataFrame(aar3,columns=['A','B','C','D'],index=[6,7,8])

# %%
pd.concat([df6,df7,df8])
# Out:
#           A         B         C         D
# 0 -1.080565  0.010229  0.437830  1.327788
# 1 -0.251145  1.593111  0.170818 -0.709254
# 2 -0.133025 -0.017357 -0.101093 -0.564040
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620
# 6 -0.071324 -0.045438  1.040886 -0.094035
# 7 -0.420844 -0.551989 -0.121098  0.190141
# 8  0.512137  0.131538 -0.331617 -1.632386

# %%
pd.concat([df6,df7,df8],axis=1)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -1.080565  0.010229  0.437830  1.327788       NaN       NaN       NaN
# 1 -0.251145  1.593111  0.170818 -0.709254       NaN       NaN       NaN
# 2 -0.133025 -0.017357 -0.101093 -0.564040       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN  0.728876  1.968435 -0.547788
# 4       NaN       NaN       NaN       NaN -2.506230  0.146960  0.606195
# 5       NaN       NaN       NaN       NaN  0.013422  0.935945  0.420623
# 6       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           D         A         B         C         D
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# ...

# %%
pd.concat([df6,df7,df8],axis=1).fillna(0)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -1.080565  0.010229  0.437830  1.327788  0.000000  0.000000  0.000000
# 1 -0.251145  1.593111  0.170818 -0.709254  0.000000  0.000000  0.000000
# 2 -0.133025 -0.017357 -0.101093 -0.564040  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.728876  1.968435 -0.547788
# 4  0.000000  0.000000  0.000000  0.000000 -2.506230  0.146960  0.606195
# 5  0.000000  0.000000  0.000000  0.000000  0.013422  0.935945  0.420623
# 6  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           D         A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
df6
# Out:
#           A         B         C         D
# 0 -1.080565  0.010229  0.437830  1.327788
# 1 -0.251145  1.593111  0.170818 -0.709254
# 2 -0.133025 -0.017357 -0.101093 -0.564040

# %%
df7
# Out:
#           A         B         C         D
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620

# %%
np.random.seed(23)
aar1=np.random.randn(3,4)
np.random.seed(23)
aar2=np.random.randn(3,4)

df11=pd.DataFrame(aar1,columns=['A','B','C','D'],index=[0,1,2])
df22=pd.DataFrame(aar2,columns=['A','B','C','D'],index=[3,4,5])

# %%
df11
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
df22
# Out:
#           A         B         C         D
# 3  0.666988  0.025813 -0.777619  0.948634
# 4  0.701672 -1.051082 -0.367548 -1.137460
# 5 -1.322148  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df22,on='A')
# Out:
#           A       B_x       C_x       D_x       B_y       C_y       D_y
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df22)
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140
