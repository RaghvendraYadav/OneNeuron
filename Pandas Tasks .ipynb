# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
#Create New Column
dollar=lambda x:float(x[1:-1])
df['item_price_Dollars']=df['item_price'].apply(dollar)

# %%
df.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price             object
# item_price_Dollars    float64
# dtype: object

# %%
#Add new Column Item Price in Ruppees
df['item_price_ruppes']=df['item_price_Dollars']*72

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                   NaN     $2.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
#  5   item_price_Dollars  4622 non-null   float64
#  6   item_price_ruppes   4622 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 252.9+ KB

# %%
df.groupby('item_name').sum()
# Out:
#                                        order_id  quantity  item_price_Dollars  \
# item_name
# 6 Pack Soft Drink                         52322        55              356.95
# Barbacoa Bowl                             53972        66              672.36
# Barbacoa Burrito                          74718        91              894.75
# Barbacoa Crispy Tacos                      5613        12              120.21
# Barbacoa Salad Bowl                        9708        10              106.40
# Barbacoa Soft Tacos                       18725        25              250.46
# Bottled Water                            175944       211              302.56
# Bowl                                        472         4               29.60
# Burrito                                    1550         6               44.40
# Canned Soda                               76396       126              137.34
# Canned Soft Drink                        304753       351              438.75
# ...

# %%
c=c.sum()

# %%
c.sort_values(['quantity'],ascending=False)
# Out:
#                                        order_id  quantity  item_price_Dollars  \
# item_name
# Chicken Bowl                             713926       761             7342.73
# Chicken Burrito                          497303       591             5575.82
# Chips and Guacamole                      449959       506             2201.04
# Steak Burrito                            328437       386             3851.43
# Canned Soft Drink                        304753       351              438.75
# Chips                                    208004       230              494.34
# Steak Bowl                               193752       221             2260.19
# Bottled Water                            175944       211              302.56
# Chips and Fresh Tomato Salsa             100419       130              361.36
# Canned Soda                               76396       126              137.34
# Chicken Salad Bowl                       117104       123             1228.75
# ...
